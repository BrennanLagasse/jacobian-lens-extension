# %% [markdown]
# # Jacobian lens — walkthrough
#
# Load a model, load a pre-fitted Jacobian lens from the Hub, apply it to a prompt, and render the interactive slice visualisation.

# %%
import jlens

jlens.configure_logging()

MODEL_NAME = "Qwen/Qwen3.5-9B"
# MODEL_NAME = "Qwen/Qwen3.6-27B"

LENS_REPO = "neuronpedia/jacobian-lens"
LENS_REVISION = "qwen-n1000"
LENS_FILE = {
    "Qwen/Qwen3.5-4B": "qwen3.5-4b/jlens/Salesforce-wikitext/Qwen3.5-4B_jacobian_lens_n1000.pt",
    "Qwen/Qwen3.5-9B": "qwen3.5-9b-pt/jlens/Salesforce-wikitext/Qwen3.5-9B-Base_jacobian_lens.pt",
    "Qwen/Qwen3.6-27B": "qwen3.6-27b/jlens/Salesforce-wikitext/Qwen3.6-27B_jacobian_lens_n1000.pt",
}[MODEL_NAME]

# %% [markdown]
# ## 1. Load the model
#
# `jlens.from_hf` wraps an already-loaded HuggingFace model into `LensModel` interface

# %%
import torch
import transformers

hf_model = transformers.AutoModelForCausalLM.from_pretrained(
    MODEL_NAME, dtype=torch.bfloat16
).cuda()
tokenizer = transformers.AutoTokenizer.from_pretrained(MODEL_NAME)
model = jlens.from_hf(hf_model, tokenizer)
model
# Out:
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/427 [00:00<?, ?it/s]
# HFLensModel(Qwen3_5ForCausalLM, n_layers=32, d_model=4096)

# %% [markdown]
# ## 2. Load a pre-fitted lens
#
# `JacobianLens.from_pretrained` pulls a `.pt` from the Hub (or a local path). The lens holds one `[d_model, d_model]` matrix per layer.

# %%
lens = jlens.JacobianLens.from_pretrained(
    LENS_REPO, filename=LENS_FILE, revision=LENS_REVISION
)
lens
# Out:
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# JacobianLens(d_model=4096, n_prompts=458, source_layers=[0..30] (31 layers))

# %% [markdown]
# ## 3. Apply: J-lens vs logit lens
#
# `lens.apply(model, prompt, positions=...)` runs one forward pass, transports each layer's residual into the final-layer basis with `J_l`, and decodes through the model's own unembedding. `use_jacobian=False` skips the transport — that's the vanilla logit lens.
#
# Below: a two-hop factual question, read out at the boot token. The J-lens surfaces interpretable tokens at layers where the logit lens is still noise.

# %%
prompt = "Fact: The currency used in the country shaped like a boot is"
layers = [
    model.n_layers // 4,
    model.n_layers // 2,
    model.n_layers // 4 * 3,
    model.n_layers - 2,
]

jlens_logits, model_logits, _ = lens.apply(model, prompt, layers=layers, positions=[-2])
logit_lens, _, _ = lens.apply(
    model, prompt, layers=layers, positions=[-2], use_jacobian=False
)


def top5(logits):
    return [tokenizer.decode([t]) for t in logits.topk(5).indices]


for layer in layers:
    print(f"L{layer:>3} logit-lens: {top5(logit_lens[layer][0])}")
    print(f"L{layer:>3} J-lens:     {top5(jlens_logits[layer][0])}")
print(f"model:           {top5(model_logits[0])}")
# Out:
# L  8 logit-lens: ['形', '-shaped', '�', 'long', ' shape']
# L  8 J-lens:     [' ‘', '’)', ' boots', '’', ' ’']
# L 16 logit-lens: ['-shaped', 'ola', 'la', 'LEC', 'bled']
# L 16 J-lens:     [' Italy', ' Italian', '意大利', 'Italy', ' Mediterranean']
# L 24 logit-lens: ['-shaped', '形', ' shaped', '形状', ' shape']
# L 24 J-lens:     [' Italy', '意大利', '-shaped', 'Italy', ' italia']
# L 30 logit-lens: [' is', ' (', ' boot', ' was', ',']
# L 30 J-lens:     [' is', '.', ',', ' boot', '-shaped']
# model:           [' is', '.', '\n', ' in', ',']

# %% [markdown]
# ## 4. Render a slice page (inline)
#
# `compute_slice` + `build_page` produce an interactive position × layer view of the lens's token ranks (the `?` in the corner explains the controls). `mode="embed"` inlines everything so the page is self-contained.

# %%
import gzip
import json

from jlens.examples import EXAMPLES, resolve_prompt
from jlens.vis import build_page, compute_slice, notebook_iframe

# English gloss for Qwen's Chinese/Japanese/Korean vocab tokens (machine-
# generated, best-effort), shown next to
# the token in the page (alt_token=).
gloss = {
    int(k): v for k, v in json.load(gzip.open("assets/qwen_gloss.json.gz")).items()
}

example = next(e for e in EXAMPLES if e.slug == "multihop")
prompt = resolve_prompt(example, tokenizer)

slice_data = compute_slice(
    model,
    lens,
    prompt,
    layer_stride=2,
    # Empirically on Qwen, the interesting word tokens trail punctuation and
    # single-character tokens in the raw top-K; mask to word-like tokens only.
    mask_display=True,
)
page, _, _ = build_page(
    slice_data,
    prompt,
    title=example.section,
    description=example.description,
    alt_token=gloss,
)
notebook_iframe(page)
# Out:
# <iframe style="width:100%;height:620px;border:0" srcdoc="&lt;!doctype html&gt;
# &lt;!--
# Copyright 2026 Anthropic PBC
# SPDX-License-Identifier: Apache-2.0
# --&gt;
# &lt;html lang=&quot;en&quot;&gt;&lt;head&gt;
# &lt;meta charset=&quot;UTF-8&quot;&gt;
# &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,initial-scale=1&quot;&gt;
# &lt;title&gt;Multi-hop reasoning&lt;/title&gt;
# &lt;script&gt;
# // https://d3js.org v7.9.0 Copyright 2010-2023 Mike Bostock
# !function(t,n){&quot;object&quot;==typeof exports&amp;&amp;&quot;undefined&quot;!=typeof module?n(exports):&quot;function&quot;==typeof define&amp;&amp;define.amd?define([&quot;exports&quot;],n):n((t=&quot;undefined&quot;!=typeof globalThis?globalThis:t||self).d3=t.d3||{})}(this,(function(t){&quot;use strict&quot;;function n(t,n){return null==t||null==n?NaN:t&lt;n?-1:t&gt;n?1:t&gt;=n?0:NaN}function e(t,n){return null==t||null==n?NaN:n&lt;t?-1:n&gt;t?1:n&gt;=t?0:NaN}function r(t){let r,o,a;function u(t,n,e=0,i=t.length){if(e&lt;i){if(0!==r(n,n))return i;do{const r=e+i&gt;&gt;&gt;1;o(t[r],n)&lt;0?e=r+1:i=r}while(e&lt;i)}return e}return 2!==t.length?(r=n,o=(e,r)=&gt;n(t(e),r),a=(n,e)=&gt;t(n)-e):(r=t===n||t===e?t:i,o=t,a=t),{left:u,center:function(t,n,e=0,r=t.length){const i=u(t,n,e,r-1);return i&gt;e&amp;&amp;a(t[i-1],n)&gt;-a(t[i],n)?i-1:i},right:function(t,n,e=0,i=t.length){if(e&lt;i){if(0!==r(n,n))return i;do{const r=e+i&gt;&gt;&gt;1;o(t[r],n)&lt;=0?e=r+1:i=r}while(e&lt;i)}return e}}}function i(){return 0}function o(t){return null===t?NaN:+t}const a=r(n),u=a.right,c=a.left,f=r(o).center;var s=u;const l=d(y),h=d((function(t){const n=y(t);return(t,e,r,i,o)=&gt;{n(t,e,(r&lt;&lt;=2)+0,(i&lt;&lt;=2)+0,o&lt;&lt;=2),n(t,e,r+1,i+1,o),n(t,e,r+2,i+2,o),n(t,e,r+3,i+3,o)}}));function d(t){return function(n,e,r=e){if(!((e=+e)&gt;=0))throw new RangeError(&quot;invalid rx&quot;);if(!((r=+r)&gt;=0))throw new RangeError(&quot;invalid ry&quot;);let{data:i,width:o,height:a}=n;if(!((o=Math.floor(o))&gt;=0))throw new RangeError(&quot;invalid width&quot;);if(!((a=Math.floor(void 0!==a?a:i.length/o))&gt;=0))throw new RangeError(&quot;invalid height&quot;);if(!o||!a||!e&amp;&amp;!r)return n;const u=e&amp;&amp;t(e),c=r&amp;&amp;t(r),f=i.slice();return u&amp;&amp;c?(p(u,f,i,o,a),p(u,i,f,o,a),p(u,f,i,o,a),g(c,i,f,o,a),g(c,f,i,o,a),g(c,i,f,o,a)):u?(p(u,i,f,o,a),p(u,f,i,o,a),p(u,i,f,o,a)):c&amp;&amp;(g(c,i,f,o,a),g(c,f,i,o,a),g(c,i,f,o,a)),n}}function p(t,n,e,r,i){for(let o=0,a=r*i;o&lt;a;)t(n,e,o,o+=r,1)}function g(t,n,e,r,i){for(let o=0,a=r*i;o&lt;r;++o)t(n,e,o,o+a,r)}function y(t){const n=Math.floor(t);if(n===t)return function(t){const n=2*t+1;return(e,r,i,o,a)=&gt;{if(!((o-=a)&gt;=i))return;let u=t*r[i];const c=a*t;for(let t=i,n=i+c;t&lt;n;t+=a)u+=r[Math.min(o,t)];for(let t=i,f=o;t&lt;=f;t+=a)u+=r[Math.min(o,t+c)],e[t]=u/n,u-=r[Math.max(i,t-c)]}}(t);const e=t-n,r=2*t+1;return(t,i,o,a,u)=&gt;{if(!((a-=u)&gt;=o))return;let c=n*i[o];const f=u*n,s=f+u;for(let t=o,n=o+f;t&lt;n;t+=u)c+=i[Math.min(a,t)];for(let n=o,l=a;n&lt;=l;n+=u)c+=i[Math.min(a,n+f)],t[n]=(c+e*(i[Math.max(o,n-s)]+i[Math.min(a,n+s)]))/r,c-=i[Math.max(o,n-f)]}}function v(t,n){let e=0;if(void 0===n)for(let n of t)null!=n&amp;&amp;(n=+n)&gt;=n&amp;&amp;++e;else{let r=-1;for(let i of t)null!=(i=n(i,++r,t))&amp;&amp;(i=+i)&gt;=i&amp;&amp;++e}return e}function _(t){return 0|t.length}function b(t){return!(t&gt;0)}function m(t){return&quot;object&quot;!=typeof t||&quot;length&quot;in t?t:Array.from(t)}function x(t,n){let e,r=0,i=0,o=0;if(void 0===n)for(let n of t)null!=n&amp;&amp;(n=+n)&gt;=n&amp;&amp;(e=n-i,i+=e/++r,o+=e*(n-i));else{let a=-1;for(let u of t)null!=(u=n(u,++a,t))&amp;&amp;(u=+u)&gt;=u&amp;&amp;(e=u-i,i+=e/++r,o+=e*(u-i))}if(r&gt;1)return o/(r-1)}function w(t,n){const e=x(t,n);return e?Math.sqrt(e):e}function M(t,n){let e,r;if(void 0===n)for(const n of t)null!=n&amp;&amp;(void 0===e?n&gt;=n&amp;&amp;(e=r=n):(e&gt;n&amp;&amp;(e=n),r&lt;n&amp;&amp;(r=n)));else{let i=-1;for(let o of t)null!=(o=n(o,++i,t))&amp;&amp;(void 0===e?o&gt;=o&amp;&amp;(e=r=o):(e&gt;o&amp;&amp;(e=o),r&lt;o&amp;&amp;(r=o)))}return[e,r]}class T{constructor(){this._partials=new Float64Array(32),this._n=0}add(t){const n=this._partials;let e=0;for(let r=0;r&lt;this._n&amp;&amp;r&lt;32;r++){const i=n[r],o=t+i,a=Math.abs(t)&lt;Math.abs(i)?t-(o-i):i-(o-t);a&amp;&amp;(n[e++]=a),t=o}return n[e]=t,this._n=e+1,this}valueOf(){const t=this._partials;let n,e,r,i=this._n,o=0;if(i&gt;0){for(o=t[--i];i&gt;0&amp;&amp;(n=o,e=t[--i] ...

# %% [markdown]
# ## 5. Render a slice page (served)
#
# For longer prompts prefer `mode="fetch"`: `build_page` writes the data as sidecar files to `out_dir` and the page fetches rank files lazily on pin, so it stays small regardless of how many tokens are tracked.

# %%
import os
import threading
from functools import partial
from http.server import HTTPServer, SimpleHTTPRequestHandler
from pathlib import Path

example = next(e for e in EXAMPLES if e.slug == "blackmail")
prompt = resolve_prompt(example, tokenizer)

slice_data = compute_slice(model, lens, prompt, mask_display=True)
out_dir = Path("slices") / example.slug
page, _, _ = build_page(
    slice_data,
    prompt,
    title=example.section,
    description=example.description,
    alt_token=gloss,
    mode="fetch",
    out_dir=out_dir,
)
(out_dir / "index.html").write_text(page)

if "_jlens_httpd" not in globals():
    _handler = partial(SimpleHTTPRequestHandler, directory=os.path.abspath("slices"))
    _jlens_httpd = HTTPServer(("127.0.0.1", 0), _handler)
    threading.Thread(target=_jlens_httpd.serve_forever, daemon=True).start()
print(f"-> http://localhost:{_jlens_httpd.server_address[1]}/{example.slug}/")
# Out:
# -> http://localhost:45261/blackmail/
# 127.0.0.1 - - [30/Aug/2026 19:35:09] "GET /blackmail/ HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Aug/2026 19:35:10] "GET /blackmail/meta.json HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Aug/2026 19:35:10] code 404, message File not found
# 127.0.0.1 - - [30/Aug/2026 19:35:10] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [30/Aug/2026 19:35:10] "GET /blackmail/slice.bin HTTP/1.1" 200 -

# %% [markdown]
# ### More to explore
#
# A few more prompts are bundled in `jlens.examples.EXAMPLES` — change the `slug` above and see what surfaces, or try a prompt of your own.

# %%
for e in EXAMPLES:
    print(f"{e.slug:>24}  {e.section}")
# Out:
#                 multihop  Multi-hop reasoning
#         modulation-topic  Voluntary modulation: topic
#    modulation-arithmetic  Voluntary modulation: arithmetic
#               ascii-face  ASCII face
#               off-by-one  Bug in code
#            overdose-flag  Overdose flag
#            greatest-fear  Greatest fear (don't say it)
#                blackmail  Agentic Misalignment (blackmail honeypot)
# 127.0.0.1 - - [30/Aug/2026 19:11:37] "GET /ascii-face/ HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Aug/2026 19:11:38] "GET /ascii-face/meta.json HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Aug/2026 19:11:38] code 404, message File not found
# 127.0.0.1 - - [30/Aug/2026 19:11:38] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [30/Aug/2026 19:11:38] "GET /ascii-face/slice.bin HTTP/1.1" 200 -

# %% [markdown]
# ## 6. Fitting
#
# `fit(model, prompts)` computes `J_l` over the supplied prompts. 100 prompts is enough for a usable lens; the released lenses use 1000. `dim_batch` is the memory knob — each prompt does `ceil(d_model / dim_batch)` backward passes on a retained graph.

# %%
from jlens.examples import load_wikitext_prompts

prompts = load_wikitext_prompts(n_prompts=100)
lens = jlens.fit(
    model, prompts, dim_batch=32, max_seq_len=128, checkpoint_path="ckpt.pt"
)
lens.save("jacobian_lens.pt")
# Out:
# [  5m42s +342.83s] fit: n_layers=32 d_model=4096, fitting 31 source layers (target=L31) on 100 prompts
# NvMapMemAllocInternalTagged: 1075072515 error 12
# NvMapMemHandleAlloc: error 0
# NvMapMemAllocInternalTagged: 1075072515 error 12
# NvMapMemHandleAlloc: error 0
# NvMapMemAllocInternalTagged: 1075072515 error 12
# NvMapMemHandleAlloc: error 0
# NvMapMemAllocInternalTagged: 1075072515 error 12
# NvMapMemHandleAlloc: error 0
# NvMapMemAllocInternalTagged: 1075072515 error 12
# NvMapMemHandleAlloc: error 0
# NvMapMemAllocInternalTagged: 1075072515 error 12
# NvMapMemHandleAlloc: error 0
# NvMapMemAllocInternalTagged: 1075072515 error 12
# NvMapMemHandleAlloc: error 0
# NvMapMemAllocInternalTagged: 1075072515 error 12
# NvMapMemHandleAlloc: error 0
# NvMapMemAllocInternalTagged: 1075072515 error 12
# NvMapMemHandleAlloc: error 0
# NvMapMemAllocInternalTagged: 1075072515 error 12
# NvMapMemHandleAlloc: error 0
# NvMapMemAllocInternalTagged: 1075072515 error 12
# NvMapMemHandleAlloc: error 0
# NvMapMemAllocInternalTagged: 1075072515 error 12
# NvMapMemHandleAlloc: error 0
# NvMapMemAllocInternalTagged: 1075072515 error 12
# NvMapMemHandleAlloc: error 0
# NvMapMemAllocInternalTagged: 1075072515 error 12
# NvMapMemHandleAlloc: error 0
# NvMapMemAllocInternalTagged: 1075072515 error 12
# NvMapMemHandleAlloc: error 0
# NvMapMemAllocInternalTagged: 1075072515 error 12
# NvMapMemHandleAlloc: error 0
# NvMapMemAllocInternalTagged: 1075072515 error 12
# NvMapMemHandleAlloc: error 0
# NvMapMemAllocInternalTagged: 1075072515 error 12
# NvMapMemHandleAlloc: error 0
# NvMapMemAllocInternalTagged: 1075072515 error 12
# NvMapMemHandleAlloc: error 0
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 4
#       1 from jlens.examples import load_wikitext_prompts
#       3 prompts = load_wikitext_prompts(n_prompts=100)
# ----> 4 lens = jlens.fit(
#       5     model, prompts, dim_batch=32, max_seq_len=128, checkpoint_path="ckpt.pt"
#       6 )
#       7 lens.save("jacobian_lens.pt")
#
# File ~/Desktop/nlp_experiments/jacobian-lens-extension/jlens/fitting.py:335, in fit(model, prompts, source_layers, target_layer, dim_batch, max_seq_len, skip_first, checkpoint_path, checkpoint_every, resume)
#     333 start_time = time.perf_counter()
#     334 try:
# --> 335     per_prompt_J, seq_len, n_valid = jacobian_for_prompt(
#     336         model,
#     337         prompt,
#     338         source_layers,
#     339         target_layer=target_layer,
#     340         dim_batch=dim_batch,
#     341         max_seq_len=max_seq_len,
#     342         skip_first=skip_first,
#     343     )
#     344 except ValueError as exc:
#     345     logger.warning("  skipping prompt %d: %s", prompt_idx, exc)
#
# File ~/Desktop/nlp_experiments/jacobian-lens-extension/jlens/fitting.py:165, in jacobian_for_prompt(model, prompt, source_layers, target_layer, dim_batch, max_seq_len, skip_first)
#     154 with (
#     155     ActivationRecorder(
#     156         model.layers,
#    (...)
#     162     # One forward on the prompt replicated dim_batch times. The retained
#     163     # graph is reused for every backward pass below.
#     164     replicated_ids = input_ids.expand(dim_batch, -1)
# --> 165     model.forward(replicated_ids)
#     166     target_activation = recorder.activations[
#     167         target_layer
#     168     ]  # [dim_batch, seq_len, d_model]
#     169     source_activations = [recorder.activations[layer] for layer in source_layers]
#
# File ~/Desktop/nlp_experiments/jacobian-lens-extension/jlens/hf.py:164, in HFLensModel.forward(self, input_ids)
#     163 def forward(self, input_ids: torch.Tensor) -> Any:
# --> 164     return self._text_module(input_ids=input_ids, use_cache=False)
#
# File ~/Desktop/nlp_experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/nlp_experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/Desktop/nlp_experiments/.venv/lib/python3.10/site-packages/transformers/utils/generic.py:1068, in merge_with_config_defaults.<locals>.wrapper(self, *args, **kwargs)
#    1066             output = func(self, *args, **kwargs)
#    1067     else:
# -> 1068         output = func(self, *args, **kwargs)
#    1069 # Restore original config value
#    1070 finally:
#    1071     if is_causal is not None:
#
# File ~/Desktop/nlp_experiments/.venv/lib/python3.10/site-packages/transformers/utils/output_capturing.py:262, in capture_outputs.<locals>.wrapped_fn.<locals>.wrapper(self, *args, **kwargs)
#     260 # Run the forward
#     261 try:
# --> 262     outputs = func(self, *args, **kwargs)
#     263 # Reset the states
#     264 finally:
#     265     _active_collector.reset(output_token)
#
# File ~/Desktop/nlp_experiments/.venv/lib/python3.10/site-packages/transformers/models/qwen3_5/modeling_qwen3_5.py:1199, in Qwen3_5TextModel.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, **kwargs)
#    1196 position_embeddings = self.rotary_emb(hidden_states, position_ids)
#    1198 for i, decoder_layer in enumerate(self.layers[: self.config.num_hidden_layers]):
# -> 1199     hidden_states = decoder_layer(
#    1200         hidden_states,
#    1201         position_embeddings=position_embeddings,
#    1202         attention_mask=causal_mask_mapping[self.config.layer_types[i]],
#    1203         position_ids=text_position_ids,
#    1204         past_key_values=past_key_values,
#    1205         use_cache=use_cache,
#    1206         **kwargs,
#    1207     )
#    1209 hidden_states = self.norm(hidden_states)
#    1211 return Qwen3_5ModelOutputWithPast(
#    1212     last_hidden_state=hidden_states,
#    1213     past_key_values=past_key_values,
#    1214 )
#
# File ~/Desktop/nlp_experiments/.venv/lib/python3.10/site-packages/transformers/modeling_layers.py:114, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#     111         logger.warning_once(message)
#     113     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# --> 114 return super().__call__(*args, **kwargs)
#
# File ~/Desktop/nlp_experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/nlp_experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1879, in Module._call_impl(self, *args, **kwargs)
#    1876     return inner()
#    1878 try:
# -> 1879     return inner()
#    1880 except Exception:
#    1881     # run always called hooks if they have not already been run
#    1882     # For now only forward hooks have the always_call option but perhaps
#    1883     # this functionality should be added to full backward hooks as well.
#    1884     for hook_id, hook in _global_forward_hooks.items():
#
# File ~/Desktop/nlp_experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1827, in Module._call_impl.<locals>.inner()
#    1824     bw_hook = BackwardHook(self, full_backward_hooks, backward_pre_hooks)
#    1825     args = bw_hook.setup_input_hook(args)
# -> 1827 result = forward_call(*args, **kwargs)
#    1828 if _global_forward_hooks or self._forward_hooks:
#    1829     for hook_id, hook in (
#    1830         *_global_forward_hooks.items(),
#    1831         *self._forward_hooks.items(),
#    1832     ):
#    1833         # mark that always called hook is run
#
# File ~/Desktop/nlp_experiments/.venv/lib/python3.10/site-packages/transformers/models/qwen3_5/modeling_qwen3_5.py:768, in Qwen3_5DecoderLayer.forward(self, hidden_states, position_embeddings, attention_mask, position_ids, past_key_values, **kwargs)
#     766 # Token Mixer
#     767 if self.block_type == "linear_attention":
# --> 768     hidden_states = self.linear_attn(
#     769         hidden_states=hidden_states,
#     770         cache_params=past_key_values,
#     771         attention_mask=attention_mask,
#     772         **kwargs,
#     773     )
#     774 elif self.block_type == "full_attention":
#     775     # Self Attention
#     776     hidden_states, _ = self.self_attn(
#     777         hidden_states=hidden_states,
#     778         attention_mask=attention_mask,
#    (...)
#     782         **kwargs,
#     783     )
#
# File ~/Desktop/nlp_experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/nlp_experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/Desktop/nlp_experiments/.venv/lib/python3.10/site-packages/transformers/integrations/accelerate.py:947, in force_accelerate_hooks.<locals>.decorator.<locals>.wrapped(self, *args, **kwargs)
#     941     if hook is not None:
#     942         # Note that here we only call the hook with the module, not `*args` not `**kwargs`, as we assume the `forward`
#     943         # on which this decorator is applied is responsible to move the args and kwargs with its own hook if any. This makes
#     944         # sense as the module decorated with this should have all internal modules on the same device
#     945         hook.pre_forward(hooked_module)
# --> 947 output = forward_func(self, *args, **kwargs)
#     949 for hooked_module, hook in reversed(hooked_modules):
#     950     if hook is not None:
#     951         # Note that here we only call the hook with the module, not `output`, as we assume the `forward` on which
#     952         # this decorator is applied is responsible to move the output with its own hook if any. This makes sense
#     953         # as the module decorated with this should have all internal modules on the same device
#
# File ~/Desktop/nlp_experiments/.venv/lib/python3.10/site-packages/transformers/models/qwen3_5/modeling_qwen3_5.py:519, in Qwen3_5GatedDeltaNet.forward(self, hidden_states, cache_params, attention_mask, **kwargs)
#     506     core_attn_out, last_recurrent_state = torch_recurrent_gated_delta_rule(
#     507         query,
#     508         key,
#    (...)
#     516         **kwargs,
#     517     )
#     518 else:
# --> 519     core_attn_out, last_recurrent_state = torch_chunk_gated_delta_rule(
#     520         query,
#     521         key,
#     522         value,
#     523         g=g,
#     524         beta=beta,
#     525         initial_state=recurrent_state,
#     526         output_final_state=cache_params is not None,
#     527         use_qk_l2norm_in_kernel=True,
#     528         cu_seqlens=kwargs.pop("cu_seq_lens_q", None),
#     529         **kwargs,
#     530     )
#     532 # Update cache
#     533 if cache_params is not None:
#
# File ~/Desktop/nlp_experiments/.venv/lib/python3.10/site-packages/transformers/integrations/hub_kernels.py:797, in use_kernel_func_from_hub_with_fallback.<locals>.decorator.<locals>.wrapped(*args, **kwargs)
#     794 @functools.wraps(torch_function)
#     795 def wrapped(*args, **kwargs):
#     796     kwargs = {k: v for k, v in kwargs.items() if k in applicable_params}
# --> 797     return implementation(*args, **kwargs)
#
# File ~/Desktop/nlp_experiments/.venv/lib/python3.10/site-packages/transformers/models/qwen3_5/modeling_qwen3_5.py:265, in torch_chunk_gated_delta_rule(query, key, value, g, beta, chunk_size, initial_state, output_final_state, use_qk_l2norm_in_kernel, **kwargs)
#     263     query = l2norm(query, dim=-1, eps=1e-6)
#     264     key = l2norm(key, dim=-1, eps=1e-6)
# --> 265 query, key, value, beta, g = [
#     266     x.transpose(1, 2).contiguous().to(torch.float32) for x in (query, key, value, beta, g)
#     267 ]
#     269 batch_size, num_heads, sequence_length, k_head_dim = key.shape
#     270 v_head_dim = value.shape[-1]
#
# File ~/Desktop/nlp_experiments/.venv/lib/python3.10/site-packages/transformers/models/qwen3_5/modeling_qwen3_5.py:266, in <listcomp>(.0)
#     263     query = l2norm(query, dim=-1, eps=1e-6)
#     264     key = l2norm(key, dim=-1, eps=1e-6)
#     265 query, key, value, beta, g = [
# --> 266     x.transpose(1, 2).contiguous().to(torch.float32) for x in (query, key, value, beta, g)
#     267 ]
#     269 batch_size, num_heads, sequence_length, k_head_dim = key.shape
#     270 v_head_dim = value.shape[-1]
#
# RuntimeError: NVML_SUCCESS == r INTERNAL ASSERT FAILED at "/opt/pytorch/c10/cuda/CUDACachingAllocator.cpp":1131, please report a bug to PyTorch.
